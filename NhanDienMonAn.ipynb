# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/FoodDetection/'

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/FoodDetectionImage/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('banhbeo'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhchung'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhhoi'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhitlagai'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhmi'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhxeo'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('chalua'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('chaolong'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('pho'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('thitkhotau'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# (100, 200, 200, 3) (100,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                 input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(photos, labels, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 8s 2s/step - loss: 6415.3848 - accuracy: 0.1200
# Epoch 2/50
# 4/4 [==============================] - 7s 2s/step - loss: 2605.4368 - accuracy: 0.2000
# Epoch 3/50
# 4/4 [==============================] - 7s 2s/step - loss: 321.2715 - accuracy: 0.1900
# Epoch 4/50
# 4/4 [==============================] - 7s 2s/step - loss: 57.7110 - accuracy: 0.2400
# Epoch 5/50
# 4/4 [==============================] - 8s 2s/step - loss: 5.2086 - accuracy: 0.5400
# Epoch 6/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.7630 - accuracy: 0.6200
# Epoch 7/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.9996 - accuracy: 0.6600
# Epoch 8/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.8709 - accuracy: 0.7000
# Epoch 9/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.7367 - accuracy: 0.7300
# Epoch 10/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.4402 - accuracy: 0.8800
# Epoch 11/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.3113 - accuracy: 0.9100
# Epoch 12/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1966 - accuracy: 0.9300
# Epoch 13/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1052 - accuracy: 0.9800
# Epoch 14/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0848 - accuracy: 0.9700
# Epoch 15/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0596 - accuracy: 0.9800
# Epoch 16/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0214 - accuracy: 0.9900
# Epoch 17/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 18/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 19/50
# 4/4 [==============================] - 7s 2s/step - loss: 7.9672e-04 - accuracy: 1.0000
# Epoch 20/50
# 4/4 [==============================] - 7s 2s/step - loss: 7.1905e-05 - accuracy: 1.0000
# Epoch 21/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.1078e-05 - accuracy: 1.0000
# Epoch 22/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 23/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1380 - accuracy: 0.9900
# Epoch 24/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0441 - accuracy: 0.9900
# Epoch 25/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0246 - accuracy: 0.9900
# Epoch 26/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0272 - accuracy: 0.9900
# Epoch 27/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1604 - accuracy: 0.9800
# Epoch 28/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1088 - accuracy: 0.9800
# Epoch 29/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1090 - accuracy: 0.9500
# Epoch 30/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0213 - accuracy: 0.9900
# Epoch 31/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.1089 - accuracy: 0.9800
# Epoch 32/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0543 - accuracy: 0.9900
# Epoch 36/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0477 - accuracy: 0.9800
# Epoch 37/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 7s 2s/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.7543e-04 - accuracy: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 7s 2s/step - loss: 9.0295e-05 - accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 7s 2s/step - loss: 9.0584e-04 - accuracy: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 7s 2s/step - loss: 2.9992e-05 - accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.0604e-05 - accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.9656e-05 - accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 7s 2s/step - loss: 4.0224e-05 - accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.7660e-05 - accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.6514e-05 - accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 7s 2s/step - loss: 3.2147e-05 - accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 7s 2s/step - loss: 2.9482e-05 - accuracy: 1.0000

# %%
model.evaluate(photos,labels)
# Out:
# 4/4 [==============================] - 2s 411ms/step - loss: 2.7776e-05 - accuracy: 1.0000
# [2.7776344722951762e-05, 1.0]

# %%
model.save('10Foods_Final.h5')

# %%
from keras.models import load_model
models=load_model('10Foods_Final.h5')

# %%
classes = ["BanhBeo","BanhChung","BanhHoi","BunItLaGai","BanhMi","BanhXeo","ChaLua","ChaoLong","Pho","ThitKhoTau"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('testBanhMi.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09095892 0.10501631 0.08477084 0.09795098 0.11603355 0.10791755
#   0.10489885 0.08500622 0.10193468 0.1055121 ]]
# 'BanhMi'
